# %%
import cv2
from roboflow import Roboflow
rf = Roboflow(api_key="oazXHCZnSbmqd489bd4G")
project = rf.workspace().project("pakistani-notes-counter")
model = project.version(1).model

# infer on a local image
predictions = model.predict(r"Currency-Identification-Smart-Glasses-1\example_image.jpeg", confidence=40, overlap=30).json()

# visualize your prediction
model.predict(r"Currency-Identification-Smart-Glasses-1\example_image.jpeg", confidence=40, overlap=30).save("prediction.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
print(predictions)
# Out:
# {'predictions': [{'x': 264, 'y': 579, 'width': 237, 'height': 278, 'confidence': 0.9787607192993164, 'class': '20', 'class_id': 3, 'image_path': 'Currency-Identification-Smart-Glasses-1\\example_image.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 206, 'y': 774, 'width': 253, 'height': 296, 'confidence': 0.9746685028076172, 'class': '50', 'class_id': 4, 'image_path': 'Currency-Identification-Smart-Glasses-1\\example_image.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 200, 'y': 363, 'width': 168, 'height': 114, 'confidence': 0.9709858894348145, 'class': '10', 'class_id': 0, 'image_path': 'Currency-Identification-Smart-Glasses-1\\example_image.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 417, 'y': 712, 'width': 214, 'height': 228, 'confidence': 0.9601753950119019, 'class': '10', 'class_id': 0, 'image_path': 'Currency-Identification-Smart-Glasses-1\\example_image.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 440, 'y': 953, 'width': 196, 'heigh
# ...

# %%
total_sum = 0  

for i in range(len(predictions['predictions'])):
    classes = predictions["predictions"][i]["class"]
    classes = int(classes)
    total_sum += classes

print("Total Amount is:", total_sum)  

image_path = 'prediction.jpg'

image = cv2.imread(image_path)

text = f'Total Amount is: {total_sum}'
                                            # text sum details
font = cv2.FONT_HERSHEY_SIMPLEX
org = (50, 50)  
font_scale = 1
color = (0, 0, 255) 
thickness = 2
image_with_text = cv2.putText(image, text, org, font, font_scale, color, thickness, cv2.LINE_AA)

cv2.imshow('Image with Total Sum', image_with_text)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Total Amount is: 8240

# %%
from roboflow import Roboflow
import supervision as sv
import cv2

rf = Roboflow(api_key="oazXHCZnSbmqd489bd4G")
project = rf.workspace().project("pakistani-notes-counter")
model = project.version(1).model

result = model.predict("Currency-Identification-Smart-Glasses-1\example_image.jpeg", confidence=40, overlap=30).json()

labels = [item["class"] for item in result["predictions"]]

detections = sv.Detections.from_roboflow(result)

label_annotator = sv.LabelAnnotator()
bounding_box_annotator = sv.BoxAnnotator()

image = cv2.imread("Currency-Identification-Smart-Glasses-1\example_image.jpeg")

annotated_image = bounding_box_annotator.annotate(
    scene=image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections, labels=labels)

sv.plot_image(image=annotated_image, size=(16, 16))
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
mydict = {"Name": "Hamza", "Age": 22}
mydict.get("Address" , True)
# Out:
# True

# %%
list1 = [1,3,2]
list2 = [5,6,7]
print(list1+list2)
# Out:
# [1, 3, 2, 5, 6, 7]

# %%
my_tuples = (12,"hks", "hmz", 98)
my_tuples.index("hks")
# Out:
# 1
